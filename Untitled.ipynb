# %%
import requests

# %%
foo = requests.get('http://localhost:8080/index.html')
foo.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n    <style src="/style.css"></style>\n    <title>Hello!</title>\n  </head>\n  <body>\n    <h1>Ziggy Boi!</h1>\n    <p>Hello from Zig.</p>\n  </body>\n</html>\n\
# ...

# %%
foo = requests.get('http://www.google.com/')
foo.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="TflLJ28g0ZycFWa5p-ovvA">(function(){window.google={kEI:\'RuVAZKTNPJWqqtsPkqKxgAM\',kEXPI:\'0,1303458,55951,6059,206,4804,2316,383,246,5,1129120,1633,1196111,147,510,380089,16115,28684,22431,1361,12315,17584,4998,13228,3847,38444,2872,2891,3926,4422,3406,606,29880,788,30022,15324,432,3,1590,1,16918,2650,4,1528,2304,29062,13065,11442,5196,18243,5818,2539,4094,7596,1,42154,2,3359,10663,2373,342,23024,5679,1020,31123,4568,6255,23421,1252,5835,14968,4332,4250,3234,445,2,2,1,10957,
# ...
